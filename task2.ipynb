# %%
import sys
import time 

import pg8000.native
import psycopg2
from faker import Faker

# %%
try:
    con = psycopg2.connect(database="postgres", user="postgres", password="1", host="127.0.0.1", port="5432")
    cur = con.cursor()
    print("Cool!", con.closed)
except BaseException as be:
    print("Impossible to connect to db:", be)
    sys.exit(1)
# Out:
# Cool! 0

# %%
con.commit()

# %%
con.reset()

# %%
# create tables
cur.execute("drop table if exists purchases;")
cur.execute("drop table if exists purchases_products_list;")
cur.execute("drop table if exists products;")
cur.execute("drop table if exists sales;")
cur.execute("drop table if exists customer;")
cur.execute("create table if not exists customer (id integer primary key, name text, address text, review text)")
cur.execute("create table if not exists purchases (id integer primary key, customer_id int, constraint a foreign key (customer_id) references customer(id)); ")
cur.execute("create table if not exists products (id integer primary key, name text, details text, price int, type text)")
cur.execute("create table if not exists purchases_products_list (id integer primary key, purchase_id int, product_id int, constraint b foreign key (purchase_id) references purchases(id), constraint c foreign key (product_id) references products(id))")
cur.execute("create table if not exists sales (id integer primary key, type text, discount int)")
con.commit()

# %%
#generating values
import random
fake = Faker()

try: 
    cur.execute("delete from purchases_products_list; \
    delete from purchases; \
    delete from products; \
    delete from sales; \
    delete from customer;")
    for i in range(101):
        cur.execute(f"insert into customer (id, name, address, review) values ('{str(i)}', '{fake.name()}', '{fake.address()}', '{fake.text()}');")
    for i in range(301):
        cur.execute(f"insert into purchases (id, customer_id) values ('{str(i)}', {random.randint(0, 100)});")
    types = fake.words(20)
    for i in range(301):
        cur.execute(f"insert into products (id, name, details, price, type) values ('{str(i)}', '{fake.text(25)}', '{fake.text(50)}', {random.randint(0, 1000)}, '{types[random.randint(0, len(types)-1)]}');")
    for i in range(3000):
        cur.execute(f"insert into purchases_products_list (id, purchase_id, product_id) values ('{str(i)}', {random.randint(0, 300)}, {random.randint(0, 300)});")
    for i in range(10):
        cur.execute(f"insert into sales (id, type, discount) values ({str(i)}, '{types[random.randint(0, len(types) // 3)]}', {random.randint(0,30)});")
    con.commit()
except BaseException as e: 
    print("Error!", e)
    con.reset()

# %%
con.reset()

# %%
# Select all products purchased by the customer with discount

cur.execute("select customer.name as Name, products.name as \"Product Name\", sales.type from sales join products on sales.type = products.type join purchases_products_list p on products.id = p.product_id join purchases on p.purchase_id = purchases.id join customer on  purchases.customer_id = customer.id \
    order by customer.name, sales.type")
for r in cur:
    print(r)
# Out:
# ('Aaron Smith', 'Industry air sport but.', 'a')
# ('Aaron Smith', 'Walk thank community.', 'a')
# ('Aaron Smith', 'Walk thank community.', 'a')
# ('Aaron Smith', 'Chance far no.', 'a')
# ('Aaron Smith', 'Couple hope like.', 'a')
# ('Aaron Smith', 'Industry air sport but.', 'a')
# ('Aaron Smith', 'Couple hope like.', 'a')
# ('Aaron Smith', 'Chance far no.', 'a')
# ('Aaron Smith', 'Bill cost return.', 'by')
# ('Aaron Smith', 'Significant stand fact.', 'by')
# ('Aaron Smith', 'Fall phone world.', 'by')
# ('Aaron Smith', 'Staff one play for feel.', 'hair')
# ('Aaron Smith', 'Star begin guy leader.', 'hair')
# ('Aaron Smith', 'Star begin guy leader.', 'hair')
# ('Aaron Smith', 'Staff one play for feel.', 'hair')
# ('Aaron Smith', 'Boy field require.', 'rest')
# ('Aaron Smith', 'Food whom begin dream.', 'rest')
# ('Aaron Smith', 'Beyond since form old.', 'rest')
# ('Aaron Smith', 'Fine they word much.', 'turn')
# ('Aaron Smith', 'Fine they word much.', 'turn')
# ('Aaron Smith', 'Fine they word much.', 'turn')
# ('Aaron Smith', 'Size amount clear song.', 'turn')
# ('Aaron Smith', 'Size amount clear song.', 'turn')
# ('Aaron Smith', 'Fine they word much.', 'turn')
# ('Aaron Smith', 'Official social staff.', 'very')
# ('Aaron Smith', 'Official social staff.', 'very')
# ('Allison Jordan', 'Road final power body.', 'a')
# ('Allison Jordan', 'Walk thank community.', 'a')
# ('Allison Jordan', 'Walk thank community.', 'a')
# ('Allison Jordan', 'Wonder white learn.', 'a')
# ('Allison Jordan', 'Wonder white learn.', 'a')
# ('Allison Jordan', 'Once able group.', 'a')
# ('Allison Jordan', 'Once able group.', 'a')
# ('Allison Jordan', 'Road final power body.', 'a')
# ('Allison Jordan', 'If ability during at.', 'by')
# ('Allison Jordan', 'Local politics rich.', 'by')
# ('Allison Jordan', 'Increase name its wide.', 'by')
# ('Allison Jordan', 'Point traditional heavy.', 'by')
# ('Allison Jordan', 'Person artist team.', 'by')
# ('Allison Jordan', 'Fall phone world.', 'by')
# ('Allison Jordan', 'Must middle them page.', 'hair')
# ('Allison Jordan', 'Star begin guy leader.', 'hair')
# ('Allison Jordan', 'Star begin guy leader.', 'hair')
# ('Allison Jordan', 'Must middle them page.', 'hair')
# ('Allison Jordan', 'Part include explain.', 'rest')
# ('Allison Jordan', 'Indeed three financial.', 'rest')
# ('Allison Jordan', 'Pretty guess off stand.', 'rest')
# ('Allison Jordan', 'Relate yeah start.', 'turn')
# ('Allison Jordan', 'Relate yeah start.', 'turn')
# ('Allison Jordan', 'Since low help out site.', 'very')
# ('Allison Jordan', 'Since low help out site.', 'very')
# ('Amanda Rodriguez', 'Hot test kind play.', 'by')
# ('Amanda Wagner', 'Only decision scene.', 'a')
# ('Amanda Wagner', 'Chance far no.', 'a')
# ('Amanda Wagner', 'Chance far no.', 'a')
# ('Amanda Wagner', 'Only decision scene.', 'a')
# ('Amanda Wagner', 'Person artist team.', 'by')
# ('Amanda Wagner', 'Owner its yet.', 'by')
# ('Amanda Wagner', 'Trial through Mr lead.', 'by')
# ('Amanda Wagner', 'Should agency ok out.', 'by')
# ('Amanda Wagner', 'Power fast with term.', 'hair')
# ('Amanda Wagner', 'Power fast with term.', 'hair')
# ('Amanda Wagner', 'Must middle them page.', 'hair')
# ('Amanda Wagner', 'Staff one play for feel.', 'hair')
# ('Amanda Wagner', 'Staff one play for feel.', 'hair')
# ('Amanda Wagner', 'Staff one play for feel.', 'hair')
# ('Amanda Wagner', 'Must middle them page.', 'hair')
# ('Amanda Wagner', 'Staff one play for feel.', 'hair')
# ('Amanda Wagner', 'Ok stay black because.', 'rest')
# ('Amanda Wagner', 'Yard least enough.', 'turn')
# ('Amanda Wagner', 'Yard least enough.', 'turn')
# ('Amanda Wagner', 'Yard least enough.', 'turn')
# ('Amanda Wagner', 'Fine they word much.', 'turn')
# ('Amanda Wagner', 'Fine they word much.', 'turn')
# ('Amanda Wagner', 'Yard least enough.', 'turn')
# ('Amanda Wagner', 'Of respond what.', 'very')
# ('Amanda Wagner', 'Tax Mrs policy event.', 'very')
# ('Amanda Wagner', 'Tax Mrs policy event.', 'very')
# ('Amanda Wagner', 'Since low help out site.', 'very')
# ('Amanda Wagner', 'Since low help out site.', 'very')
# ('Amanda Wagner', 'Of respond what.', 'very')
# ('Andrea Neal', 'Condition story quickly.', 'a')
# ('Andrea Neal', 'Condition story quickly.', 'a')
# ('Andrea Neal', 'Ready while still nice.', 'by')
# ('Andrea Neal', 'If ability during at.', 'by')
# ('Andrea Neal', 'Three thank instead.', 'hair')
# ('Andrea Neal', 'Her stage mind send.', 'hair')
# ('Andrea Neal', 'Three thank instead.', 'hair')
# ('Andrea Neal', 'Her stage mind send.', 'hair')
# ('Andrea Neal', 'Animal piece fill.', 'rest')
# ('Andrea Neal', 'Part include explain.', 'rest')
# ('Andrea Neal', 'Government thank lawyer.', 'rest')
# ('Andrea Neal', 'Risk well may great.', 'rest')
# ('Andrea Neal', 'Do paper carry.', 'turn')
# ('Andrea Neal', 'Relate yeah start.', 'turn')
# ('Andrea Neal', 'Relate yeah start.', 'turn')
# ('Andrea Neal', 'Do paper carry.', 'turn')
# ('Andrea Neal', 'Of respond what.', 'very')
# ('Andrea Neal', 'Of respond what.', 'very')
# ('Andrea Neal', 'Owner treat position.', 'very')
# ('Andrea Neal', 'Tax Mrs policy event.', 'very')
# ('Andrea Neal', 'Tax Mrs policy event.', 'very')
# ('Andrea Neal', 'Admit talk least he.', 'very')
# ('Andrea Neal', 'Owner treat position.', 'very')
# ('Andrea Neal', 'Admit talk least he.', 'very')
# ('Angela Black', 'Hot test kind play.', 'by')
# ('Angela Black', 'Bill cost return.', 'by')
# ('Angela Black', 'Person artist team.', 'by')
# ('Angela Black', 'Must middle them page.', 'hair')
# ('Angela Black', 'Must middle them page.', 'hair')
# ('Angela Black', 'Catch PM oil health.', 'rest')
# ('Angela Black', 'Government thank lawyer.', 'rest')
# ('Angela Black', 'Animal piece fill.', 'rest')
# ('Angela Black', 'Animal piece fill.', 'rest')
# ('Angela Black', 'Behind nation future.', 'turn')
# ('Angela Black', 'Behind nation future.', 'turn')
# ('Angela Black', 'Place yes whose.', 'turn')
# ('Angela Black', 'Seat kitchen stage.', 'turn')
# ('Angela Black', 'Place yes whose.', 'turn')
# ('Angela Black', 'Seat kitchen stage.', 'turn')
# ('Angela Black', 'Process admit nature.', 'very')
# ('Angela Black', 'Process admit nature.', 'very')
# ('Angela Black', 'Pass player body.', 'very')
# ('Angela Black', 'Pass player body.', 'very')
# ('Angela Brown', 'Significant stand fact.', 'by')
# ('Angela Brown', 'Operation son then kind.', 'hair')
# ('Angela Brown', 'Operation son then kind.', 'hair')
# ('Angela Brown', 'Her stage mind send.', 'hair')
# ('Angela Brown', 'Her stage mind send.', 'hair')
# ('Angela Brown', 'Political would allow.', 'rest')
# ('Angela Brown', 'In range bill who go.', 'turn')
# ('Angela Brown', 'In range bill who go.', 'turn')
# ('Angela Brown', 'Say draw three person.', 'very')
# ('Angela Brown', 'Tax Mrs policy event.', 'very')
# ('Angela Brown', 'Say draw three person.', 'very')
# ('Angela Brown', 'Tax Mrs policy event.', 'very')
# ('Angela Robinson', 'Industry air sport but.', 'a')
# ('Angela Robinson', 'Industry air sport but.', 'a')
# ('Angela Robinson', 'Couple hope like.', 'a')
# ('Angela Robinson', 'Couple hope like.', 'a')
# ('Angela Robinson', 'Political would allow.', 'rest')
# ('Angela Robinson', 'Ok stay black because.', 'rest')
# ('Angela Robinson', 'Place yes whose.', 'turn')
# ('Angela Robinson', 'Place yes whose.', 'turn')
# ('Angela Walker', 'Chance far no.', 'a')
# ('Angela Walker', 'Chance far no.', 'a')
# ('Angela Walker', 'Chance far no.', 'a')
# ('Angela Walker', 'Chance far no.', 'a')
# ('Angela Walker', 'Similar you his small.', 'turn')
# ('Angela Walker', 'Similar you his small.', 'turn')
# ('Angela Wilson', 'What join move police.', 'a')
# ('Angela Wilson', 'What join move police.', 'a')
# ('Angela Wilson', 'Person artist team.', 'by')
# ('Angela Wilson', 'Increase name its wide.', 'by')
# ('Angela Wilson', 'Similar you his small.', 'turn')
# ('Angela Wilson', 'Similar you his small.', 'turn')
# ('Angela Wilson', 'Do paper carry.', 'turn')
# ('Angela Wilson', 'Do paper carry.', 'turn')
# ('Angela Wilson', 'Still nation easy.', 'very')
# ('Angela Wilson', 'Still nation easy.', 'very')
# ('Anthony Ruiz', 'What join move police.', 'a')
# ('Anthony Ruiz', 'Door ground defense.', 'a')
# ('Anthony Ruiz', 'What join move police.', 'a')
# ('Anthony Ruiz', 'Couple hope like.', 'a')
# ('Anthony Ruiz', 'Couple hope like.', 'a')
# ('Anthony Ruiz', 'Door ground defense.', 'a')
# ('Anthony Ruiz', 'Fall phone world.', 'by')
# ('Anthony Ruiz', 'In say fire.', 'by')
# ('Anthony Ruiz', 'In say fire.', 'by')
# ('Anthony Ruiz', 'Ok kind word too this.', 'by')
# ('Anthony Ruiz', 'Trial through Mr lead.', 'by')
# ('Anthony Ruiz', 'Significant stand fact.', 'by')
# ('Anthony Ruiz', 'Point traditional heavy.', 'by')
# ('Anthony Ruiz', 'Her stage mind send.', 'hair')
# ('Anthony Ruiz', 'Star begin guy leader.', 'hair')
# ('Anthony Ruiz', 'Star begin guy leader.', 'hair')
# ('Anthony Ruiz', 'Her stage mind send.', 'hair')
# ('Anthony Ruiz', 'Three thank instead.', 'hair')
# ('Anthony Ruiz', 'Three thank instead.', 'hair')
# ('Anthony Ruiz', 'Risk well may great.', 'rest')
# ('Anthony Ruiz', 'Food whom begin dream.', 'rest')
# ('Anthony Ruiz', 'Tree value strong.', 'turn')
# ('Anthony Ruiz', 'Yard least enough.', 'turn')
# ('Anthony Ruiz', 'Yard least enough.', 'turn')
# ('Anthony Ruiz', 'Tree value strong.', 'turn')
# ('Anthony Ruiz', 'Tax Mrs policy event.', 'very')
# ('Anthony Ruiz', 'Still nation easy.', 'very')
# ('Anthony Ruiz', 'Tax Mrs policy event.', 'very')
# ('Anthony Ruiz', 'Wish about natural hard.', 'very')
# ('Anthony Ruiz', 'Wish about natural hard.', 'very')
# ('Anthony Ruiz', 'Still nation easy.', 'very')
# ('Barry Howell', 'Manager believe guy.', 'a')
# ('Barry Howell', 'Manager believe guy.', 'a')
# ('Barry Howell', 'Seat kitchen stage.', 'turn')
# ('Barry Howell', 'Seat kitchen stage.', 'turn')
# ('Barry Howell', 'Dark mind meet some.', 'turn')
# ('Barry Howell', 'Dark mind meet some.', 'turn')
# ('Barry Howell', 'Wish about natural hard.', 'very')
# ('Barry Howell', 'Wish about natural hard.', 'very')
# ('Brian Austin', 'Fall phone world.', 'by')
# ('Brian Austin', 'If ability during at.', 'by')
# ('Brian Austin', 'Wait pick simple.', 'turn')
# ('Brian Austin', 'Size amount clear song.', 'turn')
# ('Brian Austin', 'Wait pick simple.', 'turn')
# ('Brian Austin', 'Size amount clear song.', 'turn')
# ('Brian Austin', 'Wish about natural hard.', 'very')
# ('Brian Austin', 'Say draw three person.', 'very')
# ('Brian Austin', 'Say draw three person.', 'very')
# ('Brian Austin', 'Change my explain.', 'very')
# ('Brian Austin', 'Wish about natural hard.', 'very')
# ('Brian Austin', 'Change my explain.', 'very')
# ('Bryan Williams', 'Industry air sport but.', 'a')
# ('Bryan Williams', 'Walk thank community.', 'a')
# ('Bryan Williams', 'Chance far no.', 'a')
# ('Bryan Williams', 'Picture sell can cost.', 'a')
# ('Bryan Williams', 'Chance far no.', 'a')
# ('Bryan Williams', 'Chance far no.', 'a')
# ('Bryan Williams', 'Walk thank community.', 'a')
# ('Bryan Williams', 'Chance far no.', 'a')
# ('Bryan Williams', 'Picture sell can cost.', 'a')
# ('Bryan Williams', 'Industry air sport but.', 'a')
# ('Bryan Williams', 'Significant stand fact.', 'by')
# ('Bryan Williams', 'In say fire.', 'by')
# ('Bryan Williams', 'Art laugh staff.', 'turn')
# ('Bryan Williams', 'Art laugh staff.', 'turn')
# ('Bryan Williams', 'Art laugh staff.', 'turn')
# ('Bryan Williams', 'Art laugh staff.', 'turn')
# ('Bryan Williams', 'Owner treat position.', 'very')
# ('Bryan Williams', 'Process admit nature.', 'very')
# ('Bryan Williams', 'Process admit nature.', 'very')
# ('Bryan Williams', 'Owner treat position.', 'very')
# ('Bryan Williams', 'Pass player body.', 'very')
# ('Bryan Williams', 'Pass player body.', 'very')
# ('Carrie Bennett', 'Once able group.', 'a')
# ('Carrie Bennett', 'Once able group.', 'a')
# ('Carrie Bennett', 'Condition story quickly.', 'a')
# ('Carrie Bennett', 'Condition story quickly.', 'a')
# ('Carrie Bennett', 'Her stage mind send.', 'hair')
# ('Carrie Bennett', 'Her stage mind send.', 'hair')
# ('Carrie Bennett', 'Beyond since form old.', 'rest')
# ('Catherine Mcdonald', 'Wonder white learn.', 'a')
# ('Catherine Mcdonald', 'Chance far no.', 'a')
# ('Catherine Mcdonald', 'Wonder white learn.', 'a')
# ('Catherine Mcdonald', 'Matter effort example.', 'a')
# ('Catherine Mcdonald', 'Industry air sport but.', 'a')
# ('Catherine Mcdonald', 'Industry air sport but.', 'a')
# ('Catherine Mcdonald', 'Chance far no.', 'a')
# ('Catherine Mcdonald', 'Matter effort example.', 'a')
# ('Catherine Mcdonald', 'Able sea education.', 'by')
# ('Catherine Mcdonald', 'If method walk.', 'by')
# ('Catherine Mcdonald', 'Increase name its wide.', 'by')
# ('Catherine Mcdonald', 'Operation son then kind.', 'hair')
# ('Catherine Mcdonald', 'Operation son then kind.', 'hair')
# ('Catherine Mcdonald', 'Kitchen community sea.', 'rest')
# ('Catherine Mcdonald', 'Beyond since form old.', 'rest')
# ('Catherine Mcdonald', 'Size amount clear song.', 'turn')
# ('Catherine Mcdonald', 'Relate yeah start.', 'turn')
# ('Catherine Mcdonald', 'Relate yeah start.', 'turn')
# ('Catherine Mcdonald', 'Seat kitchen stage.', 'turn')
# ('Catherine Mcdonald', 'Size amount clear song.', 'turn')
# ('Catherine Mcdonald', 'Tree value strong.', 'turn')
# ('Catherine Mcdonald', 'Dark mind meet some.', 'turn')
# ('Catherine Mcdonald', 'Dark mind meet some.', 'turn')
# ('Catherine Mcdonald', 'Seat kitchen stage.', 'turn')
# ('Catherine Mcdonald', 'Do paper carry.', 'turn')
# ('Catherine Mcdonald', 'Do paper carry.', 'turn')
# ('Catherine Mcdonald', 'Wait pick simple.', 'turn')
# ('Catherine Mcdonald', 'Seat kitchen stage.', 'turn')
# ('Catherine Mcdonald', 'Seat kitchen stage.', 'turn')
# ('Catherine Mcdonald', 'Wait pick simple.', 'turn')
# ('Catherine Mcdonald', 'Seat kitchen stage.', 'turn')
# ('Catherine Mcdonald', 'Tree value strong.', 'turn')
# ('Catherine Mcdonald', 'Seat kitchen stage.', 'turn')
# ('Catherine Mcdonald', 'Official social staff.', 'very')
# ('Catherine Mcdonald', 'Of respond what.', 'very')
# ('Catherine Mcdonald', 'Of respond what.', 'very')
# ('Catherine Mcdonald', 'Since low help out site.', 'very')
# ('Catherine Mcdonald', 'Since low help out site.', 'very')
# ('Catherine Mcdonald', 'Wish about natural hard.', 'very')
# ('Catherine Mcdonald', 'Wish about natural hard.', 'very')
# ('Catherine Mcdonald', 'Pass player body.', 'very')
# ('Catherine Mcdonald', 'Pass player body.', 'very')
# ('Catherine Mcdonald', 'Official social staff.', 'very')
# ('Catherine Mcdonald', 'Owner treat position.', 'very')
# ('Catherine Mcdonald', 'Owner treat position.', 'very')
# ('Charles Wilkins', 'What join move police.', 'a')
# ('Charles Wilkins', 'What join move police.', 'a')
# ('Charles Wilkins', 'What join move police.', 'a')
# ('Charles Wilkins', 'What join move police.', 'a')
# ('Charles Wilkins', 'Increase name its wide.', 'by')
# ('Charles Wilkins', 'Operation son then kind.', 'hair')
# ('Charles Wilkins', 'Operation son then kind.', 'hair')
# ('Charles Wilkins', 'Boy field require.', 'rest')
# ('Charles Wilkins', 'Pretty guess off stand.', 'rest')
# ('Charles Wilkins', 'Animal piece fill.', 'rest')
# ('Charles Wilkins', 'Wait pick simple.', 'turn')
# ('Charles Wilkins', 'Wait pick simple.', 'turn')
# ('Charles Wilkins', 'Have area least court.', 'turn')
# ('Charles Wilkins', 'Have area least court.', 'turn')
# ('Charles Wilkins', 'Wish about natural hard.', 'very')
# ('Charles Wilkins', 'Wish about natural hard.', 'very')
# ('Chase Shah', 'Matter effort example.', 'a')
# ('Chase Shah', 'Chance far no.', 'a')
# ('Chase Shah', 'Matter effort example.', 'a')
# ('Chase Shah', 'Walk thank community.', 'a')
# ('Chase Shah', 'Walk thank community.', 'a')
# ('Chase Shah', 'Road final power body.', 'a')
# ('Chase Shah', 'Road final power body.', 'a')
# ('Chase Shah', 'Couple hope like.', 'a')
# ('Chase Shah', 'Chance far no.', 'a')
# ('Chase Shah', 'Couple hope like.', 'a')
# ('Chase Shah', 'We level hold we that.', 'by')
# ('Chase Shah', 'In say fire.', 'by')
# ('Chase Shah', 'Able sea education.', 'by')
# ('Chase Shah', 'Also always thank seven.', 'hair')
# ('Chase Shah', 'Also always thank seven.', 'hair')
# ('Chase Shah', 'Beyond since form old.', 'rest')
# ('Chase Shah', 'Pretty guess off stand.', 'rest')
# ('Chase Shah', 'Part include explain.', 'rest')
# ('Chase Shah', 'Fine they word much.', 'turn')
# ('Chase Shah', 'Tree value strong.', 'turn')
# ('Chase Shah', 'Tree value strong.', 'turn')
# ('Chase Shah', 'Fine they word much.', 'turn')
# ('Chase Shah', 'Fine they word much.', 'turn')
# ('Chase Shah', 'Fine they word much.', 'turn')
# ('Chase Shah', 'Behind nation future.', 'turn')
# ('Chase Shah', 'Behind nation future.', 'turn')
# ('Chase Shah', 'Say draw three person.', 'very')
# ('Chase Shah', 'Process admit nature.', 'very')
# ('Chase Shah', 'Process admit nature.', 'very')
# ('Chase Shah', 'Say draw three person.', 'very')
# ('Chase Shah', 'Wish about natural hard.', 'very')
# ('Chase Shah', 'Wish about natural hard.', 'very')
# ('Christopher Mcfarland', 'Increase name its wide.', 'by')
# ('Christopher Mcfarland', 'But effort much watch.', 'by')
# ('Christopher Mcfarland', 'News long produce stop.', 'hair')
# ('Christopher Mcfarland', 'News long produce stop.', 'hair')
# ('Christopher Mcfarland', 'Dark mind meet some.', 'turn')
# ('Christopher Mcfarland', 'Dark mind meet some.', 'turn')
# ('Christopher Mcfarland', 'Seat kitchen stage.', 'turn')
# ('Christopher Mcfarland', 'Seat kitchen stage.', 'turn')
# ('Christopher Mcfarland', 'Size amount clear song.', 'turn')
# ('Christopher Mcfarland', 'Size amount clear song.', 'turn')
# ('Christopher Mcfarland', 'Process admit nature.', 'very')
# ('Christopher Mcfarland', 'Process admit nature.', 'very')
# ('Colin Robertson', 'Walk thank community.', 'a')
# ('Colin Robertson', 'Walk thank community.', 'a')
# ('Danielle Richardson', 'Matter effort example.', 'a')
# ('Danielle Richardson', 'Picture sell can cost.', 'a')
# ('Danielle Richardson', 'Picture sell can cost.', 'a')
# ('Danielle Richardson', 'Door ground defense.', 'a')
# ('Danielle Richardson', 'Door ground defense.', 'a')
# ('Danielle Richardson', 'Matter effort example.', 'a')
# ('Danielle Richardson', 'Owner its yet.', 'by')
# ('Danielle Richardson', 'News long produce stop.', 'hair')
# ('Danielle Richardson', 'News long produce stop.', 'hair')
# ('Danielle Richardson', 'Son ask loss baby door.', 'rest')
# ('Danielle Richardson', 'Boy field require.', 'rest')
# ('Danielle Richardson', 'List let role receive.', 'turn')
# ('Danielle Richardson', 'List let role receive.', 'turn')
# ('Danielle Richardson', 'List let role receive.', 'turn')
# ('Danielle Richardson', 'List let role receive.', 'turn')
# ('Danielle Richardson', 'Relate yeah start.', 'turn')
# ('Danielle Richardson', 'Relate yeah start.', 'turn')
# ('Danny Terry', 'Once able group.', 'a')
# ('Danny Terry', 'Once able group.', 'a')
# ('Danny Terry', 'Once able group.', 'a')
# ('Danny Terry', 'Once able group.', 'a')
# ('Danny Terry', 'Walk thank community.', 'a')
# ('Danny Terry', 'Walk thank community.', 'a')
# ('Danny Terry', 'Small population world.', 'hair')
# ('Danny Terry', 'Her stage mind send.', 'hair')
# ('Danny Terry', 'Her stage mind send.', 'hair')
# ('Danny Terry', 'Small population world.', 'hair')
# ('Danny Terry', 'Political would allow.', 'rest')
# ('Danny Terry', 'Part include explain.', 'rest')
# ('Danny Terry', 'Behind nation future.', 'turn')
# ('Danny Terry', 'Behind nation future.', 'turn')
# ('Danny Terry', 'Still nation easy.', 'very')
# ('Danny Terry', 'Still nation easy.', 'very')
# ('David Barker', 'Manager believe guy.', 'a')
# ('David Barker', 'What join move police.', 'a')
# ('David Barker', 'Manager believe guy.', 'a')
# ('David Barker', 'What join move police.', 'a')
# ('David Barker', 'Door ground defense.', 'a')
# ('David Barker', 'What join move police.', 'a')
# ('David Barker', 'Door ground defense.', 'a')
# ('David Barker', 'What join move police.', 'a')
# ('David Barker', 'But effort much watch.', 'by')
# ('David Barker', 'Window common unit it.', 'by')
# ('David Barker', 'Point traditional heavy.', 'by')
# ('David Barker', 'Person artist team.', 'by')
# ('David Barker', 'Significant stand fact.', 'by')
# ('David Barker', 'Bar factor course make.', 'by')
# ('David Barker', 'Her stage mind send.', 'hair')
# ('David Barker', 'Her stage mind send.', 'hair')
# ('David Barker', 'Grow one mission.', 'hair')
# ('David Barker', 'Grow one mission.', 'hair')
# ('David Barker', 'Political would allow.', 'rest')
# ('David Barker', 'Beyond since form old.', 'rest')
# ('David Barker', 'Ok stay black because.', 'rest')
# ('David Barker', 'Part include explain.', 'rest')
# ('David Barker', 'Hair head and.', 'turn')
# ('David Barker', 'Hair head and.', 'turn')
# ('David Barker', 'Size amount clear song.', 'turn')
# ('David Barker', 'Size amount clear song.', 'turn')
# ('David Barker', 'Process admit nature.', 'very')
# ('David Barker', 'Official social staff.', 'very')
# ('David Barker', 'Official social staff.', 'very')
# ('David Barker', 'Process admit nature.', 'very')
# ('David Koch', 'Condition story quickly.', 'a')
# ('David Koch', 'Condition story quickly.', 'a')
# ('David Koch', 'Bar factor course make.', 'by')
# ('David Love', 'Might it early.', 'a')
# ('David Love', 'Chance far no.', 'a')
# ('David Love', 'Might it early.', 'a')
# ('David Love', 'Chance far no.', 'a')
# ('David Love', 'Fall phone world.', 'by')
# ('David Love', 'Grow one mission.', 'hair')
# ('David Love', 'Grow one mission.', 'hair')
# ('David Love', 'Similar you his small.', 'turn')
# ('David Love', 'Similar you his small.', 'turn')
# ('David Love', 'Process admit nature.', 'very')
# ('David Love', 'Process admit nature.', 'very')
# ('Deborah Jones', 'Picture sell can cost.', 'a')
# ('Deborah Jones', 'Picture sell can cost.', 'a')
# ('Deborah Jones', 'Able sea education.', 'by')
# ('Deborah Jones', 'Star begin guy leader.', 'hair')
# ('Deborah Jones', 'Star begin guy leader.', 'hair')
# ('Deborah Jones', 'Part include explain.', 'rest')
# ('Deborah Jones', 'Beyond since form old.', 'rest')
# ('Deborah Jones', 'My stock rest check.', 'rest')
# ('Deborah Jones', 'Have area least court.', 'turn')
# ('Deborah Jones', 'Have area least court.', 'turn')
# ('Deborah Jones', 'Owner treat position.', 'very')
# ('Deborah Jones', 'Owner treat position.', 'very')
# ('Deborah Jones', 'Change my explain.', 'very')
# ('Deborah Jones', 'Change my explain.', 'very')
# ('Denise Gardner', 'Small population world.', 'hair')
# ('Denise Gardner', 'Small population world.', 'hair')
# ('Denise Gardner', 'Also always thank seven.', 'hair')
# ('Denise Gardner', 'Also always thank seven.', 'hair')
# ('Denise Gardner', 'Art laugh staff.', 'turn')
# ('Denise Gardner', 'List let role receive.', 'turn')
# ('Denise Gardner', 'Have area least court.', 'turn')
# ('Denise Gardner', 'Art laugh staff.', 'turn')
# ('Denise Gardner', 'In range bill who go.', 'turn')
# ('Denise Gardner', 'List let role receive.', 'turn')
# ('Denise Gardner', 'Have area least court.', 'turn')
# ('Denise Gardner', 'In range bill who go.', 'turn')
# ('Denise Gardner', 'List let role receive.', 'turn')
# ('Denise Gardner', 'List let role receive.', 'turn')
# ('Denise Gardner', 'Owner treat position.', 'very')
# ('Denise Gardner', 'Owner treat position.', 'very')
# ('Diana Wheeler', 'If ability during at.', 'by')
# ('Diana Wheeler', 'Point traditional heavy.', 'by')
# ('Diana Wheeler', 'Must middle them page.', 'hair')
# ('Diana Wheeler', 'Must middle them page.', 'hair')
# ('Diana Wheeler', 'Political would allow.', 'rest')
# ('Diana Wheeler', 'Indeed three financial.', 'rest')
# ('Diana Wheeler', 'Hair head and.', 'turn')
# ('Diana Wheeler', 'Hair head and.', 'turn')
# ('Elizabeth Charles', 'Owner its yet.', 'by')
# ('Elizabeth Charles', 'Star begin guy leader.', 'hair')
# ('Elizabeth Charles', 'Star begin guy leader.', 'hair')
# ('Elizabeth Charles', 'List let role receive.', 'turn')
# ('Elizabeth Charles', 'List let role receive.', 'turn')
# ('Elizabeth Charles', 'Wish about natural hard.', 'very')
# ('Elizabeth Charles', 'Admit talk least he.', 'very')
# ('Elizabeth Charles', 'Admit talk least he.', 'very')
# ('Elizabeth Charles', 'Say draw three person.', 'very')
# ('Elizabeth Charles', 'Say draw three person.', 'very')
# ('Elizabeth Charles', 'Wish about natural hard.', 'very')
# ('Eric Edwards', 'Walk thank community.', 'a')
# ('Eric Edwards', 'Walk thank community.', 'a')
# ('Eric Edwards', 'Government thank lawyer.', 'rest')
# ('Erica Howard', 'Once able group.', 'a')
# ('Erica Howard', 'Couple hope like.', 'a')
# ('Erica Howard', 'Once able group.', 'a')
# ('Erica Howard', 'Couple hope like.', 'a')
# ('Erica Howard', 'We level hold we that.', 'by')
# ('Erica Howard', 'Also always thank seven.', 'hair')
# ('Erica Howard', 'Seek bring name.', 'hair')
# ('Erica Howard', 'Must middle them page.', 'hair')
# ('Erica Howard', 'Seek bring name.', 'hair')
# ('Erica Howard', 'Must middle them page.', 'hair')
# ('Erica Howard', 'Seek bring name.', 'hair')
# ('Erica Howard', 'Three thank instead.', 'hair')
# ('Erica Howard', 'Also always thank seven.', 'hair')
# ('Erica Howard', 'Seek bring name.', 'hair')
# ('Erica Howard', 'Three thank instead.', 'hair')
# ('Erica Howard', 'Also always thank seven.', 'hair')
# ('Erica Howard', 'Also always thank seven.', 'hair')
# ('Erica Howard', 'Part include explain.', 'rest')
# ('Erica Howard', 'Indeed three financial.', 'rest')
# ('Erica Howard', 'Behind nation future.', 'turn')
# ('Erica Howard', 'Behind nation future.', 'turn')
# ('Erica Howard', 'Behind nation future.', 'turn')
# ('Erica Howard', 'Behind nation future.', 'turn')
# ('Erica Howard', 'Place yes whose.', 'turn')
# ('Erica Howard', 'Yard least enough.', 'turn')
# ('Erica Howard', 'Yard least enough.', 'turn')
# ('Erica Howard', 'Place yes whose.', 'turn')
# ('Erica Howard', 'Hair head and.', 'turn')
# ('Erica Howard', 'Hair head and.', 'turn')
# ('Erica Howard', 'Owner treat position.', 'very')
# ('Erica Howard', 'Owner treat position.', 'very')
# ('Gabriela Reid', 'Bill cost return.', 'by')
# ('Gabriela Reid', 'Able sea education.', 'by')
# ('Gabriela Reid', 'Person artist team.', 'by')
# ('Gabriela Reid', 'Trial through Mr lead.', 'by')
# ('Gabriela Reid', 'But effort much watch.', 'by')
# ('Gabriela Reid', 'Her stage mind send.', 'hair')
# ('Gabriela Reid', 'Seek bring name.', 'hair')
# ('Gabriela Reid', 'Seek bring name.', 'hair')
# ('Gabriela Reid', 'Her stage mind send.', 'hair')
# ('Gabriela Reid', 'Pretty guess off stand.', 'rest')
# ('Gabriela Reid', 'Relate yeah start.', 'turn')
# ('Gabriela Reid', 'List let role receive.', 'turn')
# ('Gabriela Reid', 'List let role receive.', 'turn')
# ('Gabriela Reid', 'Relate yeah start.', 'turn')
# ('Gabriela Reid', 'Pass player body.', 'very')
# ('Gabriela Reid', 'Pass player body.', 'very')
# ('Harry Johnson', 'Trial through Mr lead.', 'by')
# ('Harry Johnson', 'If method walk.', 'by')
# ('Harry Johnson', 'Bill cost return.', 'by')
# ('Harry Johnson', 'Ok kind word too this.', 'by')
# ('Harry Johnson', 'Grow one mission.', 'hair')
# ('Harry Johnson', 'Grow one mission.', 'hair')
# ('Harry Johnson', 'Indeed three financial.', 'rest')
# ('Harry Johnson', 'Son ask loss baby door.', 'rest')
# ('Harry Johnson', 'Behind nation future.', 'turn')
# ('Harry Johnson', 'Behind nation future.', 'turn')
# ('Harry Johnson', 'Tree value strong.', 'turn')
# ('Harry Johnson', 'Tree value strong.', 'turn')
# ('Harry Johnson', 'Yard least enough.', 'turn')
# ('Harry Johnson', 'Yard least enough.', 'turn')
# ('Jamie Barker', 'Road final power body.', 'a')
# ('Jamie Barker', 'Once able group.', 'a')
# ('Jamie Barker', 'Road final power body.', 'a')
# ('Jamie Barker', 'Once able group.', 'a')
# ('Jamie Barker', 'Bar factor course make.', 'by')
# ('Jamie Barker', 'Trial through Mr lead.', 'by')
# ('Jamie Barker', 'If method walk.', 'by')
# ('Jamie Barker', 'Small population world.', 'hair')
# ('Jamie Barker', 'Small population world.', 'hair')
# ('Jamie Barker', 'Boy field require.', 'rest')
# ('Jamie Barker', 'Government thank lawyer.', 'rest')
# ('Jamie Barker', 'Catch PM oil health.', 'rest')
# ('Jamie Barker', 'Wish about natural hard.', 'very')
# ('Jamie Barker', 'Wish about natural hard.', 'very')
# ('Jennifer Caldwell', 'Manager believe guy.', 'a')
# ('Jennifer Caldwell', 'Smile together cost.', 'a')
# ('Jennifer Caldwell', 'Smile together cost.', 'a')
# ('Jennifer Caldwell', 'Manager believe guy.', 'a')
# ('Jennifer Caldwell', 'Manager believe guy.', 'a')
# ('Jennifer Caldwell', 'Manager believe guy.', 'a')
# ('Jennifer Caldwell', 'Fall phone world.', 'by')
# ('Jennifer Caldwell', 'If ability during at.', 'by')
# ('Jennifer Caldwell', 'In say fire.', 'by')
# ('Jennifer Caldwell', 'Also always thank seven.', 'hair')
# ('Jennifer Caldwell', 'Power fast with term.', 'hair')
# ('Jennifer Caldwell', 'Also always thank seven.', 'hair')
# ('Jennifer Caldwell', 'Power fast with term.', 'hair')
# ('Jennifer Rodriguez', 'Industry air sport but.', 'a')
# ('Jennifer Rodriguez', 'Smile together cost.', 'a')
# ('Jennifer Rodriguez', 'Smile together cost.', 'a')
# ('Jennifer Rodriguez', 'Industry air sport but.', 'a')
# ('Jennifer Rodriguez', 'Ok kind word too this.', 'by')
# ('Jennifer Rodriguez', 'Owner treat position.', 'very')
# ('Jennifer Rodriguez', 'Owner treat position.', 'very')
# ('Joshua Conway', 'Picture sell can cost.', 'a')
# ('Joshua Conway', 'Might it early.', 'a')
# ('Joshua Conway', 'Might it early.', 'a')
# ('Joshua Conway', 'Condition story quickly.', 'a')
# ('Joshua Conway', 'Condition story quickly.', 'a')
# ('Joshua Conway', 'Picture sell can cost.', 'a')
# ('Joshua Conway', 'Manager believe guy.', 'a')
# ('Joshua Conway', 'Manager believe guy.', 'a')
# ('Joshua Conway', 'Condition story quickly.', 'a')
# ('Joshua Conway', 'Condition story quickly.', 'a')
# ('Joshua Conway', 'Picture sell can cost.', 'a')
# ('Joshua Conway', 'Picture sell can cost.', 'a')
# ('Joshua Conway', 'Picture sell can cost.', 'a')
# ('Joshua Conway', 'Picture sell can cost.', 'a')
# ('Joshua Conway', 'Walk thank community.', 'a')
# ('Joshua Conway', 'Walk thank community.', 'a')
# ('Joshua Conway', 'In say fire.', 'by')
# ('Joshua Conway', 'Trial through Mr lead.', 'by')
# ('Joshua Conway', 'Bill cost return.', 'by')
# ('Joshua Conway', 'Hair head and.', 'turn')
# ('Joshua Conway', 'Hair head and.', 'turn')
# ('Joshua Conway', 'Tree value strong.', 'turn')
# ('Joshua Conway', 'Have area least court.', 'turn')
# ('Joshua Conway', 'Have area least court.', 'turn')
# ('Joshua Conway', 'Tree value strong.', 'turn')
# ('Joshua Conway', 'Admit talk least he.', 'very')
# ('Joshua Conway', 'Admit talk least he.', 'very')
# ('Joshua Horn', 'But effort much watch.', 'by')
# ('Joshua Horn', 'Significant stand fact.', 'by')
# ('Joshua Horn', 'Worry hit partner claim.', 'turn')
# ('Joshua Horn', 'Worry hit partner claim.', 'turn')
# ('Justin Gray', 'Only decision scene.', 'a')
# ('Justin Gray', 'Only decision scene.', 'a')
# ('Justin Gray', 'Only decision scene.', 'a')
# ('Justin Gray', 'Picture sell can cost.', 'a')
# ('Justin Gray', 'Picture sell can cost.', 'a')
# ('Justin Gray', 'Only decision scene.', 'a')
# ('Justin Gray', 'Local politics rich.', 'by')
# ('Justin Gray', 'Window common unit it.', 'by')
# ('Justin Gray', 'Point traditional heavy.', 'by')
# ('Justin Gray', 'But effort much watch.', 'by')
# ('Justin Gray', 'Person artist team.', 'by')
# ('Justin Gray', 'We level hold we that.', 'by')
# ('Justin Gray', 'Ready while still nice.', 'by')
# ('Justin Gray', 'In say fire.', 'by')
# ('Justin Gray', 'Grow one mission.', 'hair')
# ('Justin Gray', 'Star begin guy leader.', 'hair')
# ('Justin Gray', 'Star begin guy leader.', 'hair')
# ('Justin Gray', 'Must middle them page.', 'hair')
# ('Justin Gray', 'Must middle them page.', 'hair')
# ('Justin Gray', 'Grow one mission.', 'hair')
# ('Justin Gray', 'Political would allow.', 'rest')
# ('Justin Gray', 'Kitchen community sea.', 'rest')
# ('Justin Gray', 'Ok stay black because.', 'rest')
# ('Justin Gray', 'Relate yeah start.', 'turn')
# ('Justin Gray', 'Relate yeah start.', 'turn')
# ('Justin Gray', 'Official social staff.', 'very')
# ('Justin Gray', 'Official social staff.', 'very')
# ('Justin Hale', 'Couple hope like.', 'a')
# ('Justin Hale', 'Couple hope like.', 'a')
# ('Justin Hale', 'Staff one play for feel.', 'hair')
# ('Justin Hale', 'Staff one play for feel.', 'hair')
# ('Justin Hale', 'Admit talk least he.', 'very')
# ('Justin Hale', 'Admit talk least he.', 'very')
# ('Kathleen Adams', 'Might it early.', 'a')
# ('Kathleen Adams', 'Matter effort example.', 'a')
# ('Kathleen Adams', 'Matter effort example.', 'a')
# ('Kathleen Adams', 'Smile together cost.', 'a')
# ('Kathleen Adams', 'Smile together cost.', 'a')
# ('Kathleen Adams', 'Might it early.', 'a')
# ('Kathleen Adams', 'Bar factor course make.', 'by')
# ('Kathleen Adams', 'Significant stand fact.', 'by')
# ('Kathleen Adams', 'Significant stand fact.', 'by')
# ('Kathleen Adams', 'Power fast with term.', 'hair')
# ('Kathleen Adams', 'Grow one mission.', 'hair')
# ('Kathleen Adams', 'Grow one mission.', 'hair')
# ('Kathleen Adams', 'Power fast with term.', 'hair')
# ('Kathleen Adams', 'My stock rest check.', 'rest')
# ('Kathleen Adams', 'Government thank lawyer.', 'rest')
# ('Kathleen Adams', 'Yard least enough.', 'turn')
# ('Kathleen Adams', 'Yard least enough.', 'turn')
# ('Kathleen Adams', 'Still nation easy.', 'very')
# ('Kathleen Adams', 'Still nation easy.', 'very')
# ('Kathleen Adams', 'Pass player body.', 'very')
# ('Kathleen Adams', 'Pass player body.', 'very')
# ('Katie Boyd', 'Road final power body.', 'a')
# ('Katie Boyd', 'Road final power body.', 'a')
# ('Katie Boyd', 'Ready while still nice.', 'by')
# ('Katie Boyd', 'Part include explain.', 'rest')
# ('Katie Boyd', 'Part include explain.', 'rest')
# ('Katie Wright', 'Must middle them page.', 'hair')
# ('Katie Wright', 'Must middle them page.', 'hair')
# ('Katie Wright', 'Political would allow.', 'rest')
# ('Katie Wright', 'Beyond since form old.', 'rest')
# ('Katie Wright', 'Dark mind meet some.', 'turn')
# ('Katie Wright', 'Place yes whose.', 'turn')
# ('Katie Wright', 'Relate yeah start.', 'turn')
# ('Katie Wright', 'Place yes whose.', 'turn')
# ('Katie Wright', 'Relate yeah start.', 'turn')
# ('Katie Wright', 'Place yes whose.', 'turn')
# ('Katie Wright', 'Place yes whose.', 'turn')
# ('Katie Wright', 'Worry hit partner claim.', 'turn')
# ('Katie Wright', 'Worry hit partner claim.', 'turn')
# ('Katie Wright', 'Dark mind meet some.', 'turn')
# ('Katie Wright', 'My none evidence.', 'very')
# ('Katie Wright', 'My none evidence.', 'very')
# ('Katie Wright', 'Owner treat position.', 'very')
# ('Katie Wright', 'Owner treat position.', 'very')
# ('Katie Wright', 'Owner treat position.', 'very')
# ('Katie Wright', 'Owner treat position.', 'very')
# ('Kendra Roach', 'Able sea education.', 'by')
# ('Kendra Roach', 'Hot test kind play.', 'by')
# ('Kendra Roach', 'Point traditional heavy.', 'by')
# ('Kendra Roach', 'Person artist team.', 'by')
# ('Kendra Roach', 'Seek bring name.', 'hair')
# ('Kendra Roach', 'Seek bring name.', 'hair')
# ('Kendra Roach', 'Star begin guy leader.', 'hair')
# ('Kendra Roach', 'Star begin guy leader.', 'hair')
# ('Kendra Roach', 'Part include explain.', 'rest')
# ('Kendra Roach', 'Wait pick simple.', 'turn')
# ('Kendra Roach', 'In range bill who go.', 'turn')
# ('Kendra Roach', 'Wait pick simple.', 'turn')
# ('Kendra Roach', 'In range bill who go.', 'turn')
# ('Kenneth Turner', 'Smile together cost.', 'a')
# ('Kenneth Turner', 'Smile together cost.', 'a')
# ('Kenneth Turner', 'Significant stand fact.', 'by')
# ('Kenneth Turner', 'Person artist team.', 'by')
# ('Kenneth Turner', 'Power fast with term.', 'hair')
# ('Kenneth Turner', 'Power fast with term.', 'hair')
# ('Kenneth Turner', 'My stock rest check.', 'rest')
# ('Kenneth Turner', 'Risk well may great.', 'rest')
# ('Kenneth Turner', 'Indeed three financial.', 'rest')
# ('Kenneth Turner', 'Hair head and.', 'turn')
# ('Kenneth Turner', 'Place yes whose.', 'turn')
# ('Kenneth Turner', 'Hair head and.', 'turn')
# ('Kenneth Turner', 'Place yes whose.', 'turn')
# ('Kenneth Turner', 'Admit talk least he.', 'very')
# ('Kenneth Turner', 'Owner treat position.', 'very')
# ('Kenneth Turner', 'Admit talk least he.', 'very')
# ('Kenneth Turner', 'Owner treat position.', 'very')
# ('Kenneth Turner', 'Owner treat position.', 'very')
# ('Kenneth Turner', 'Owner treat position.', 'very')
# ('Kerri Moore', 'Road final power body.', 'a')
# ('Kerri Moore', 'Road final power body.', 'a')
# ('Kerri Moore', 'Owner its yet.', 'by')
# ('Kerri Moore', 'Able sea education.', 'by')
# ('Kerri Moore', 'Three thank instead.', 'hair')
# ('Kerri Moore', 'Small population world.', 'hair')
# ('Kerri Moore', 'Small population world.', 'hair')
# ('Kerri Moore', 'Three thank instead.', 'hair')
# ('Kerri Moore', 'My stock rest check.', 'rest')
# ('Kerri Moore', 'Process admit nature.', 'very')
# ('Kerri Moore', 'Still nation easy.', 'very')
# ('Kerri Moore', 'Process admit nature.', 'very')
# ('Kerri Moore', 'Still nation easy.', 'very')
# ('Kevin House', 'What join move police.', 'a')
# ('Kevin House', 'Might it early.', 'a')
# ('Kevin House', 'Might it early.', 'a')
# ('Kevin House', 'What join move police.', 'a')
# ('Kevin House', 'Trial through Mr lead.', 'by')
# ('Kevin House', 'Should agency ok out.', 'by')
# ('Kevin House', 'Small population world.', 'hair')
# ('Kevin House', 'Small population world.', 'hair')
# ('Kevin House', 'Part include explain.', 'rest')
# ('Kevin House', 'Hair head and.', 'turn')
# ('Kevin House', 'Wait pick simple.', 'turn')
# ('Kevin House', 'Hair head and.', 'turn')
# ('Kevin House', 'Wait pick simple.', 'turn')
# ('Kevin House', 'Owner treat position.', 'very')
# ('Kevin House', 'Owner treat position.', 'very')
# ('Kevin Paul', 'Smile together cost.', 'a')
# ('Kevin Paul', 'What join move police.', 'a')
# ('Kevin Paul', 'Couple hope like.', 'a')
# ('Kevin Paul', 'What join move police.', 'a')
# ('Kevin Paul', 'Smile together cost.', 'a')
# ('Kevin Paul', 'Couple hope like.', 'a')
# ('Kevin Paul', 'Power fast with term.', 'hair')
# ('Kevin Paul', 'Power fast with term.', 'hair')
# ('Kevin Paul', 'Her stage mind send.', 'hair')
# ('Kevin Paul', 'Her stage mind send.', 'hair')
# ('Kevin Paul', 'Star begin guy leader.', 'hair')
# ('Kevin Paul', 'Star begin guy leader.', 'hair')
# ('Kevin Paul', 'Animal piece fill.', 'rest')
# ('Kevin Paul', 'Food whom begin dream.', 'rest')
# ('Kevin Paul', 'My none evidence.', 'very')
# ('Kevin Paul', 'My none evidence.', 'very')
# ('Kimberly Hernandez', 'Walk thank community.', 'a')
# ('Kimberly Hernandez', 'Industry air sport but.', 'a')
# ('Kimberly Hernandez', 'Smile together cost.', 'a')
# ('Kimberly Hernandez', 'Smile together cost.', 'a')
# ('Kimberly Hernandez', 'Couple hope like.', 'a')
# ('Kimberly Hernandez', 'Couple hope like.', 'a')
# ('Kimberly Hernandez', 'Smile together cost.', 'a')
# ('Kimberly Hernandez', 'Once able group.', 'a')
# ('Kimberly Hernandez', 'Once able group.', 'a')
# ('Kimberly Hernandez', 'Smile together cost.', 'a')
# ('Kimberly Hernandez', 'Condition story quickly.', 'a')
# ('Kimberly Hernandez', 'Condition story quickly.', 'a')
# ('Kimberly Hernandez', 'Industry air sport but.', 'a')
# ('Kimberly Hernandez', 'Walk thank community.', 'a')
# ('Kimberly Hernandez', 'Should agency ok out.', 'by')
# ('Kimberly Hernandez', 'Grow one mission.', 'hair')
# ('Kimberly Hernandez', 'Staff one play for feel.', 'hair')
# ('Kimberly Hernandez', 'Staff one play for feel.', 'hair')
# ('Kimberly Hernandez', 'Grow one mission.', 'hair')
# ('Kimberly Hernandez', 'Staff one play for feel.', 'hair')
# ('Kimberly Hernandez', 'Staff one play for feel.', 'hair')
# ('Kimberly Hernandez', 'Seek bring name.', 'hair')
# ('Kimberly Hernandez', 'Seek bring name.', 'hair')
# ('Kimberly Hernandez', 'Small population world.', 'hair')
# ('Kimberly Hernandez', 'Small population world.', 'hair')
# ('Kimberly Hernandez', 'Type mouth scene space.', 'rest')
# ('Kimberly Hernandez', 'Political would allow.', 'rest')
# ('Kimberly Hernandez', 'Seat kitchen stage.', 'turn')
# ('Kimberly Hernandez', 'Seat kitchen stage.', 'turn')
# ('Kimberly Hernandez', 'List let role receive.', 'turn')
# ('Kimberly Hernandez', 'List let role receive.', 'turn')
# ('Kimberly Hernandez', 'Similar you his small.', 'turn')
# ('Kimberly Hernandez', 'Worry hit partner claim.', 'turn')
# ('Kimberly Hernandez', 'In range bill who go.', 'turn')
# ('Kimberly Hernandez', 'Relate yeah start.', 'turn')
# ('Kimberly Hernandez', 'Worry hit partner claim.', 'turn')
# ('Kimberly Hernandez', 'Relate yeah start.', 'turn')
# ('Kimberly Hernandez', 'In range bill who go.', 'turn')
# ('Kimberly Hernandez', 'Similar you his small.', 'turn')
# ('Kimberly Hernandez', 'Relate yeah start.', 'turn')
# ('Kimberly Hernandez', 'Relate yeah start.', 'turn')
# ('Kimberly Hernandez', 'Since low help out site.', 'very')
# ('Kimberly Hernandez', 'Since low help out site.', 'very')
# ('Kimberly Peterson', 'Wonder white learn.', 'a')
# ('Kimberly Peterson', 'Couple hope like.', 'a')
# ('Kimberly Peterson', 'Couple hope like.', 'a')
# ('Kimberly Peterson', 'Wonder white learn.', 'a')
# ('Kimberly Peterson', 'Also always thank seven.', 'hair')
# ('Kimberly Peterson', 'Also always thank seven.', 'hair')
# ('Kimberly Peterson', 'Political would allow.', 'rest')
# ('Kimberly Peterson', 'List let role receive.', 'turn')
# ('Kimberly Peterson', 'List let role receive.', 'turn')
# ('Kimberly Peterson', 'Since low help out site.', 'very')
# ('Kimberly Peterson', 'Since low help out site.', 'very')
# ('Kimberly Peterson', 'Since low help out site.', 'very')
# ('Kimberly Peterson', 'Since low help out site.', 'very')
# ('Laura Carroll', 'Once able group.', 'a')
# ('Laura Carroll', 'Condition story quickly.', 'a')
# ('Laura Carroll', 'Condition story quickly.', 'a')
# ('Laura Carroll', 'Industry air sport but.', 'a')
# ('Laura Carroll', 'Industry air sport but.', 'a')
# ('Laura Carroll', 'Once able group.', 'a')
# ('Laura Carroll', 'Ready while still nice.', 'by')
# ('Laura Carroll', 'Bar factor course make.', 'by')
# ('Laura Carroll', 'Increase name its wide.', 'by')
# ('Laura Carroll', 'Bar factor course make.', 'by')
# ('Laura Carroll', 'Operation son then kind.', 'hair')
# ('Laura Carroll', 'Operation son then kind.', 'hair')
# ('Laura Carroll', 'News long produce stop.', 'hair')
# ('Laura Carroll', 'News long produce stop.', 'hair')
# ('Laura Carroll', 'Small population world.', 'hair')
# ('Laura Carroll', 'Small population world.', 'hair')
# ('Laura Carroll', 'Indeed three financial.', 'rest')
# ('Laura Carroll', 'Risk well may great.', 'rest')
# ('Laura Carroll', 'Catch PM oil health.', 'rest')
# ('Laura Carroll', 'Son ask loss baby door.', 'rest')
# ('Laura Carroll', 'Animal piece fill.', 'rest')
# ('Laura Carroll', 'Hair head and.', 'turn')
# ('Laura Carroll', 'Behind nation future.', 'turn')
# ('Laura Carroll', 'Hair head and.', 'turn')
# ('Laura Carroll', 'Hair head and.', 'turn')
# ('Laura Carroll', 'Hair head and.', 'turn')
# ('Laura Carroll', 'Behind nation future.', 'turn')
# ('Laura Carroll', 'My none evidence.', 'very')
# ('Laura Carroll', 'Of respond what.', 'very')
# ('Laura Carroll', 'Of respond what.', 'very')
# ('Laura Carroll', 'Owner treat position.', 'very')
# ('Laura Carroll', 'My none evidence.', 'very')
# ('Laura Carroll', 'Owner treat position.', 'very')
# ('Leslie Brown', 'Manager believe guy.', 'a')
# ('Leslie Brown', 'Only decision scene.', 'a')
# ('Leslie Brown', 'Only decision scene.', 'a')
# ('Leslie Brown', 'Manager believe guy.', 'a')
# ('Leslie Brown', 'Road final power body.', 'a')
# ('Leslie Brown', 'Road final power body.', 'a')
# ('Leslie Brown', 'Smile together cost.', 'a')
# ('Leslie Brown', 'Smile together cost.', 'a')
# ('Leslie Brown', 'Industry air sport but.', 'a')
# ('Leslie Brown', 'Industry air sport but.', 'a')
# ('Leslie Brown', 'Once able group.', 'a')
# ('Leslie Brown', 'Once able group.', 'a')
# ('Leslie Brown', 'Wonder white learn.', 'a')
# ('Leslie Brown', 'Wonder white learn.', 'a')
# ('Leslie Brown', 'Hot test kind play.', 'by')
# ('Leslie Brown', 'Bar factor course make.', 'by')
# ('Leslie Brown', 'Seek bring name.', 'hair')
# ('Leslie Brown', 'Seek bring name.', 'hair')
# ('Leslie Brown', 'Kitchen community sea.', 'rest')
# ('Leslie Brown', 'Pretty guess off stand.', 'rest')
# ('Leslie Brown', 'Food whom begin dream.', 'rest')
# ('Leslie Brown', 'Boy field require.', 'rest')
# ('Leslie Brown', 'Government thank lawyer.', 'rest')
# ('Leslie Brown', 'Kitchen community sea.', 'rest')
# ('Lindsey Petty', 'Nation concern south be.', 'a')
# ('Lindsey Petty', 'Nation concern south be.', 'a')
# ('Lindsey Petty', 'Point traditional heavy.', 'by')
# ('Lindsey Petty', 'Window common unit it.', 'by')
# ('Lindsey Petty', 'Local politics rich.', 'by')
# ('Lindsey Petty', 'Seek bring name.', 'hair')
# ('Lindsey Petty', 'Seek bring name.', 'hair')
# ('Lindsey Petty', 'Similar you his small.', 'turn')
# ('Lindsey Petty', 'Similar you his small.', 'turn')
# ('Lindsey Petty', 'Owner treat position.', 'very')
# ('Lindsey Petty', 'Change my explain.', 'very')
# ('Lindsey Petty', 'Owner treat position.', 'very')
# ('Lindsey Petty', 'Change my explain.', 'very')
# ('Lisa Donaldson', 'Nation concern south be.', 'a')
# ('Lisa Donaldson', 'What join move police.', 'a')
# ('Lisa Donaldson', 'Nation concern south be.', 'a')
# ('Lisa Donaldson', 'What join move police.', 'a')
# ('Lisa Donaldson', 'Should agency ok out.', 'by')
# ('Lisa Donaldson', 'Ok kind word too this.', 'by')
# ('Lisa Donaldson', 'Fall phone world.', 'by')
# ('Lisa Donaldson', 'Increase name its wide.', 'by')
# ('Lisa Donaldson', 'Bill cost return.', 'by')
# ('Lisa Donaldson', 'If ability during at.', 'by')
# ('Lisa Donaldson', 'Star begin guy leader.', 'hair')
# ('Lisa Donaldson', 'Star begin guy leader.', 'hair')
# ('Lisa Donaldson', 'Ok stay black because.', 'rest')
# ('Lisa Donaldson', 'In range bill who go.', 'turn')
# ('Lisa Donaldson', 'In range bill who go.', 'turn')
# ('Lisa Donaldson', 'Still nation easy.', 'very')
# ('Lisa Donaldson', 'Still nation easy.', 'very')
# ('Lisa Donaldson', 'Owner treat position.', 'very')
# ('Lisa Donaldson', 'Owner treat position.', 'very')
# ('Lisa Hall', 'Once able group.', 'a')
# ('Lisa Hall', 'What join move police.', 'a')
# ('Lisa Hall', 'Once able group.', 'a')
# ('Lisa Hall', 'What join move police.', 'a')
# ('Lisa Hall', 'Political would allow.', 'rest')
# ('Lisa Hall', 'Type mouth scene space.', 'rest')
# ('Lisa Hall', 'Kitchen community sea.', 'rest')
# ('Lisa Hall', 'Say draw three person.', 'very')
# ('Lisa Hall', 'Of respond what.', 'very')
# ('Lisa Hall', 'Of respond what.', 'very')
# ('Lisa Hall', 'Say draw three person.', 'very')
# ('Mark Thomas', 'Door ground defense.', 'a')
# ('Mark Thomas', 'Couple hope like.', 'a')
# ('Mark Thomas', 'Wonder white learn.', 'a')
# ('Mark Thomas', 'Wonder white learn.', 'a')
# ('Mark Thomas', 'Couple hope like.', 'a')
# ('Mark Thomas', 'Nation concern south be.', 'a')
# ('Mark Thomas', 'Nation concern south be.', 'a')
# ('Mark Thomas', 'Matter effort example.', 'a')
# ('Mark Thomas', 'Matter effort example.', 'a')
# ('Mark Thomas', 'Door ground defense.', 'a')
# ('Mark Thomas', 'Hot test kind play.', 'by')
# ('Mark Thomas', 'Fall phone world.', 'by')
# ('Mark Thomas', 'Point traditional heavy.', 'by')
# ('Mark Thomas', 'If method walk.', 'by')
# ('Mark Thomas', 'My stock rest check.', 'rest')
# ('Mark Thomas', 'Boy field require.', 'rest')
# ('Mark Thomas', 'Political would allow.', 'rest')
# ('Mark Thomas', 'Relate yeah start.', 'turn')
# ('Mark Thomas', 'Tree value strong.', 'turn')
# ('Mark Thomas', 'Tree value strong.', 'turn')
# ('Mark Thomas', 'Relate yeah start.', 'turn')
# ('Mark Thomas', 'Admit talk least he.', 'very')
# ('Mark Thomas', 'Admit talk least he.', 'very')
# ('Mark Thomas', 'Pass player body.', 'very')
# ('Mark Thomas', 'Pass player body.', 'very')
# ('Matthew Moore', 'Once able group.', 'a')
# ('Matthew Moore', 'Once able group.', 'a')
# ('Matthew Moore', 'We level hold we that.', 'by')
# ('Matthew Moore', 'Should agency ok out.', 'by')
# ('Matthew Moore', 'In say fire.', 'by')
# ('Matthew Moore', 'Staff one play for feel.', 'hair')
# ('Matthew Moore', 'Staff one play for feel.', 'hair')
# ('Matthew Moore', 'Indeed three financial.', 'rest')
# ('Matthew Moore', 'Size amount clear song.', 'turn')
# ('Matthew Moore', 'Size amount clear song.', 'turn')
# ('Matthew Moore', 'Say draw three person.', 'very')
# ('Matthew Moore', 'Say draw three person.', 'very')
# ('Matthew Moore', 'Since low help out site.', 'very')
# ('Matthew Moore', 'Owner treat position.', 'very')
# ('Matthew Moore', 'Owner treat position.', 'very')
# ('Matthew Moore', 'Since low help out site.', 'very')
# ('Matthew Tran', 'Increase name its wide.', 'by')
# ('Matthew Tran', 'Owner its yet.', 'by')
# ('Matthew Tran', 'We level hold we that.', 'by')
# ('Matthew Tran', 'We level hold we that.', 'by')
# ('Matthew Tran', 'Local politics rich.', 'by')
# ('Matthew Tran', 'Star begin guy leader.', 'hair')
# ('Matthew Tran', 'Star begin guy leader.', 'hair')
# ('Matthew Tran', 'Beyond since form old.', 'rest')
# ('Matthew Tran', 'Beyond since form old.', 'rest')
# ('Matthew Tran', 'Have area least court.', 'turn')
# ('Matthew Tran', 'Have area least court.', 'turn')
# ('Matthew Tran', 'Say draw three person.', 'very')
# ('Matthew Tran', 'Say draw three person.', 'very')
# ('Matthew Tran', 'Still nation easy.', 'very')
# ('Matthew Tran', 'Still nation easy.', 'very')
# ('Megan Tucker', 'But effort much watch.', 'by')
# ('Megan Tucker', 'Point traditional heavy.', 'by')
# ...
# ('Sabrina Barry', 'Condition story quickly.', 'a')
# ('Sabrina Barry', 'Walk thank community.', 'a')
# ('Sabrina Barry', 'Only decision scene.', 'a')
# ('Sabrina Barry', 'Industry air sport but.', 'a')
# ('Sabrina Barry', 'Industry air sport but.', 'a')
# ('Sabrina Barry', 'Condition story quickly.', 'a')
# ('Sabrina Barry', 'Condition story quickly.', 'a')
# ('Sabrina Barry', 'Walk thank community.', 'a')
# ('Sabrina Barry', 'In say fire.', 'by')
# ('Sabrina Barry', 'Hot test kind play.', 'by')
# ('Sabrina Barry', 'Animal piece fill.', 'rest')
# ('Sabrina Barry', 'Risk well may great.', 'rest')
# ('Sabrina Barry', 'Political would allow.', 'rest')
# ('Sabrina Barry', 'Type mouth scene space.', 'rest')
# ('Sabrina Barry', 'My stock rest check.', 'rest')
# ('Sabrina Barry', 'Type mouth scene space.', 'rest')
# ('Sabrina Barry', 'Pretty guess off stand.', 'rest')
# ('Sabrina Barry', 'Government thank lawyer.', 'rest')
# ('Sabrina Barry', 'Indeed three financial.', 'rest')
# ('Sabrina Barry', 'Kitchen community sea.', 'rest')
# ('Sabrina Barry', 'Tree value strong.', 'turn')
# ('Sabrina Barry', 'Dark mind meet some.', 'turn')
# ('Sabrina Barry', 'Tree value strong.', 'turn')
# ('Sabrina Barry', 'Dark mind meet some.', 'turn')
# ('Sabrina Barry', 'My none evidence.', 'very')
# ('Sabrina Barry', 'Tax Mrs policy event.', 'very')
# ('Sabrina Barry', 'My none evidence.', 'very')
# ('Sabrina Barry', 'Tax Mrs policy event.', 'very')
# ('Sabrina Hensley', 'Condition story quickly.', 'a')
# ('Sabrina Hensley', 'Condition story quickly.', 'a')
# ('Sabrina Hensley', 'Road final power body.', 'a')
# ('Sabrina Hensley', 'Road final power body.', 'a')
# ('Sabrina Hensley', 'Matter effort example.', 'a')
# ('Sabrina Hensley', 'Chance far no.', 'a')
# ('Sabrina Hensley', 'Matter effort example.', 'a')
# ('Sabrina Hensley', 'Chance far no.', 'a')
# ('Sabrina Hensley', 'Local politics rich.', 'by')
# ('Sabrina Hensley', 'Bill cost return.', 'by')
# ('Sabrina Hensley', 'If method walk.', 'by')
# ('Sabrina Hensley', 'Person artist team.', 'by')
# ('Sabrina Hensley', 'Son ask loss baby door.', 'rest')
# ('Sabrina Hensley', 'My stock rest check.', 'rest')
# ('Sabrina Hensley', 'Indeed three financial.', 'rest')
# ('Sabrina Hensley', 'Type mouth scene space.', 'rest')
# ('Sabrina Hensley', 'Boy field require.', 'rest')
# ('Sabrina Hensley', 'Boy field require.', 'rest')
# ('Sabrina Hensley', 'Son ask loss baby door.', 'rest')
# ('Sabrina Hensley', 'Boy field require.', 'rest')
# ('Sabrina Hensley', 'Food whom begin dream.', 'rest')
# ('Sabrina Hensley', 'Ok stay black because.', 'rest')
# ('Sabrina Hensley', 'Say draw three person.', 'very')
# ('Sabrina Hensley', 'Say draw three person.', 'very')
# ('Sabrina Hensley', 'Say draw three person.', 'very')
# ('Sabrina Hensley', 'Process admit nature.', 'very')
# ('Sabrina Hensley', 'Process admit nature.', 'very')
# ('Sabrina Hensley', 'Say draw three person.', 'very')
# ('Sarah Chandler', 'Also always thank seven.', 'hair')
# ('Sarah Chandler', 'Star begin guy leader.', 'hair')
# ('Sarah Chandler', 'Also always thank seven.', 'hair')
# ('Sarah Chandler', 'Star begin guy leader.', 'hair')
# ('Sarah Chandler', 'Part include explain.', 'rest')
# ('Sarah Chandler', 'Indeed three financial.', 'rest')
# ('Sarah Chandler', 'Place yes whose.', 'turn')
# ('Sarah Chandler', 'Place yes whose.', 'turn')
# ('Sean Morris', 'Industry air sport but.', 'a')
# ('Sean Morris', 'Industry air sport but.', 'a')
# ('Sean Morris', 'Significant stand fact.', 'by')
# ('Sean Morris', 'Should agency ok out.', 'by')
# ('Sean Morris', 'Window common unit it.', 'by')
# ('Sean Morris', 'Grow one mission.', 'hair')
# ('Sean Morris', 'Grow one mission.', 'hair')
# ('Sean Morris', 'Son ask loss baby door.', 'rest')
# ('Sean Morris', 'Food whom begin dream.', 'rest')
# ('Sean Morris', 'Son ask loss baby door.', 'rest')
# ('Sean Morris', 'Catch PM oil health.', 'rest')
# ('Sean Morris', 'My stock rest check.', 'rest')
# ('Sean Morris', 'Son ask loss baby door.', 'rest')
# ('Sean Morris', 'Place yes whose.', 'turn')
# ('Sean Morris', 'Hair head and.', 'turn')
# ('Sean Morris', 'Hair head and.', 'turn')
# ('Sean Morris', 'Dark mind meet some.', 'turn')
# ('Sean Morris', 'Dark mind meet some.', 'turn')
# ('Sean Morris', 'Do paper carry.', 'turn')
# ('Sean Morris', 'Do paper carry.', 'turn')
# ('Sean Morris', 'Place yes whose.', 'turn')
# ('Sean Morris', 'Process admit nature.', 'very')
# ('Sean Morris', 'Process admit nature.', 'very')
# ('Stanley Christian', 'Matter effort example.', 'a')
# ('Stanley Christian', 'Might it early.', 'a')
# ('Stanley Christian', 'Smile together cost.', 'a')
# ('Stanley Christian', 'Smile together cost.', 'a')
# ('Stanley Christian', 'Might it early.', 'a')
# ('Stanley Christian', 'Only decision scene.', 'a')
# ('Stanley Christian', 'Once able group.', 'a')
# ('Stanley Christian', 'Once able group.', 'a')
# ('Stanley Christian', 'Only decision scene.', 'a')
# ('Stanley Christian', 'Matter effort example.', 'a')
# ('Stanley Christian', 'Should agency ok out.', 'by')
# ('Stanley Christian', 'Increase name its wide.', 'by')
# ('Stanley Christian', 'Bill cost return.', 'by')
# ('Stanley Christian', 'Increase name its wide.', 'by')
# ('Stanley Christian', 'Hot test kind play.', 'by')
# ('Stanley Christian', 'Power fast with term.', 'hair')
# ('Stanley Christian', 'Three thank instead.', 'hair')
# ('Stanley Christian', 'Three thank instead.', 'hair')
# ('Stanley Christian', 'Three thank instead.', 'hair')
# ('Stanley Christian', 'Power fast with term.', 'hair')
# ('Stanley Christian', 'Three thank instead.', 'hair')
# ('Stanley Christian', 'Son ask loss baby door.', 'rest')
# ('Stanley Christian', 'Ok stay black because.', 'rest')
# ('Stanley Christian', 'Catch PM oil health.', 'rest')
# ('Stanley Christian', 'Kitchen community sea.', 'rest')
# ('Stanley Christian', 'Part include explain.', 'rest')
# ('Stanley Christian', 'Have area least court.', 'turn')
# ('Stanley Christian', 'Have area least court.', 'turn')
# ('Stanley Christian', 'Tax Mrs policy event.', 'very')
# ('Stanley Christian', 'Admit talk least he.', 'very')
# ('Stanley Christian', 'Since low help out site.', 'very')
# ('Stanley Christian', 'Admit talk least he.', 'very')
# ('Stanley Christian', 'Process admit nature.', 'very')
# ('Stanley Christian', 'Since low help out site.', 'very')
# ('Stanley Christian', 'Process admit nature.', 'very')
# ('Stanley Christian', 'My none evidence.', 'very')
# ('Stanley Christian', 'Tax Mrs policy event.', 'very')
# ('Stanley Christian', 'My none evidence.', 'very')
# ('Summer Faulkner', 'Wonder white learn.', 'a')
# ('Summer Faulkner', 'Wonder white learn.', 'a')
# ('Summer Faulkner', 'Fine they word much.', 'turn')
# ('Summer Faulkner', 'Wait pick simple.', 'turn')
# ('Summer Faulkner', 'Wait pick simple.', 'turn')
# ('Summer Faulkner', 'Do paper carry.', 'turn')
# ('Summer Faulkner', 'Do paper carry.', 'turn')
# ('Summer Faulkner', 'Dark mind meet some.', 'turn')
# ('Summer Faulkner', 'Dark mind meet some.', 'turn')
# ('Summer Faulkner', 'Fine they word much.', 'turn')
# ('Summer Faulkner', 'Of respond what.', 'very')
# ('Summer Faulkner', 'Of respond what.', 'very')
# ('Tammy Sutton', 'What join move police.', 'a')
# ('Tammy Sutton', 'What join move police.', 'a')
# ('Tammy Sutton', 'Hot test kind play.', 'by')
# ('Tammy Sutton', 'Significant stand fact.', 'by')
# ('Tammy Sutton', 'Fine they word much.', 'turn')
# ('Tammy Sutton', 'Fine they word much.', 'turn')
# ('Tammy Sutton', 'Admit talk least he.', 'very')
# ('Tammy Sutton', 'Admit talk least he.', 'very')
# ('Tina Rivera', 'Wonder white learn.', 'a')
# ('Tina Rivera', 'Might it early.', 'a')
# ('Tina Rivera', 'Might it early.', 'a')
# ('Tina Rivera', 'Wonder white learn.', 'a')
# ('Tina Rivera', 'Smile together cost.', 'a')
# ('Tina Rivera', 'Smile together cost.', 'a')
# ('Tina Rivera', 'What join move police.', 'a')
# ('Tina Rivera', 'What join move police.', 'a')
# ('Tina Rivera', 'Also always thank seven.', 'hair')
# ('Tina Rivera', 'Small population world.', 'hair')
# ('Tina Rivera', 'Small population world.', 'hair')
# ('Tina Rivera', 'Staff one play for feel.', 'hair')
# ('Tina Rivera', 'Staff one play for feel.', 'hair')
# ('Tina Rivera', 'Also always thank seven.', 'hair')
# ('Tina Rivera', 'Political would allow.', 'rest')
# ('Tina Rivera', 'Government thank lawyer.', 'rest')
# ('Tina Rivera', 'Beyond since form old.', 'rest')
# ('Tina Rivera', 'Do paper carry.', 'turn')
# ('Tina Rivera', 'Do paper carry.', 'turn')
# ('Tina Rivera', 'Pass player body.', 'very')
# ('Tina Rivera', 'Official social staff.', 'very')
# ('Tina Rivera', 'Official social staff.', 'very')
# ('Tina Rivera', 'Of respond what.', 'very')
# ('Tina Rivera', 'Of respond what.', 'very')
# ('Tina Rivera', 'Pass player body.', 'very')
# ('Tony Mcbride', 'Walk thank community.', 'a')
# ('Tony Mcbride', 'Walk thank community.', 'a')
# ('Tony Mcbride', 'Wonder white learn.', 'a')
# ('Tony Mcbride', 'Wonder white learn.', 'a')
# ('Tony Mcbride', 'Point traditional heavy.', 'by')
# ('Tony Mcbride', 'Able sea education.', 'by')
# ('Tony Mcbride', 'If ability during at.', 'by')
# ('Tony Mcbride', 'Grow one mission.', 'hair')
# ('Tony Mcbride', 'Grow one mission.', 'hair')
# ('Tony Mcbride', 'Kitchen community sea.', 'rest')
# ('Tony Mcbride', 'Of respond what.', 'very')
# ('Tony Mcbride', 'Of respond what.', 'very')
# ('Tony Scott', 'Couple hope like.', 'a')
# ('Tony Scott', 'Couple hope like.', 'a')
# ('Tony Scott', 'Significant stand fact.', 'by')
# ('Tony Scott', 'If ability during at.', 'by')
# ('Tony Scott', 'Government thank lawyer.', 'rest')
# ('Tony Scott', 'Political would allow.', 'rest')
# ('Tony Scott', 'Ok stay black because.', 'rest')
# ('Tony Scott', 'Seat kitchen stage.', 'turn')
# ('Tony Scott', 'Hair head and.', 'turn')
# ('Tony Scott', 'Hair head and.', 'turn')
# ('Tony Scott', 'Seat kitchen stage.', 'turn')
# ('Tony Scott', 'Tax Mrs policy event.', 'very')
# ('Tony Scott', 'Tax Mrs policy event.', 'very')
# ('Tyler Walters', 'Chance far no.', 'a')
# ('Tyler Walters', 'Nation concern south be.', 'a')
# ('Tyler Walters', 'Chance far no.', 'a')
# ('Tyler Walters', 'Nation concern south be.', 'a')
# ('Tyler Walters', 'Owner its yet.', 'by')
# ('Tyler Walters', 'Yard least enough.', 'turn')
# ('Tyler Walters', 'Yard least enough.', 'turn')
# ('Tyler Walters', 'Yard least enough.', 'turn')
# ('Tyler Walters', 'Yard least enough.', 'turn')
# ('Tyler Walters', 'Official social staff.', 'very')
# ('Tyler Walters', 'Official social staff.', 'very')
# ('Tyler Wilkinson', 'Behind nation future.', 'turn')
# ('Tyler Wilkinson', 'Behind nation future.', 'turn')
# ('Victor Davis', 'Wonder white learn.', 'a')
# ('Victor Davis', 'Wonder white learn.', 'a')
# ('Victor Davis', 'Also always thank seven.', 'hair')
# ('Victor Davis', 'Also always thank seven.', 'hair')
# ('Victor Davis', 'Political would allow.', 'rest')
# ('Victor Davis', 'Part include explain.', 'rest')
# ('Victor Davis', 'Kitchen community sea.', 'rest')
# ('Victor Davis', 'Catch PM oil health.', 'rest')
# ('Victor Davis', 'Seat kitchen stage.', 'turn')
# ('Victor Davis', 'Yard least enough.', 'turn')
# ('Victor Davis', 'Yard least enough.', 'turn')
# ('Victor Davis', 'Similar you his small.', 'turn')
# ('Victor Davis', 'Similar you his small.', 'turn')
# ('Victor Davis', 'Seat kitchen stage.', 'turn')
# ('William Montoya', 'Wonder white learn.', 'a')
# ('William Montoya', 'Only decision scene.', 'a')
# ('William Montoya', 'Wonder white learn.', 'a')
# ('William Montoya', 'Only decision scene.', 'a')
# ('William Montoya', 'Bar factor course make.', 'by')
# ('William Montoya', 'Indeed three financial.', 'rest')
# ('William Montoya', 'Type mouth scene space.', 'rest')
# ('William Montoya', 'Part include explain.', 'rest')
# ('William Montoya', 'Indeed three financial.', 'rest')
# ('William Montoya', 'My stock rest check.', 'rest')
# ('William Montoya', 'Yard least enough.', 'turn')
# ('William Montoya', 'List let role receive.', 'turn')
# ('William Montoya', 'List let role receive.', 'turn')
# ('William Montoya', 'Yard least enough.', 'turn')
# ('William Montoya', 'Seat kitchen stage.', 'turn')
# ('William Montoya', 'Seat kitchen stage.', 'turn')
# ('William Montoya', 'Official social staff.', 'very')
# ('William Montoya', 'Tax Mrs policy event.', 'very')
# ('William Montoya', 'Tax Mrs policy event.', 'very')
# ('William Montoya', 'Official social staff.', 'very')
# ('William Pace', 'Nation concern south be.', 'a')
# ('William Pace', 'Nation concern south be.', 'a')
# ('William Pace', 'Road final power body.', 'a')
# ('William Pace', 'Road final power body.', 'a')
# ('William Pace', 'Wonder white learn.', 'a')
# ('William Pace', 'Wonder white learn.', 'a')
# ('William Pace', 'Bar factor course make.', 'by')
# ('William Pace', 'Fall phone world.', 'by')
# ('William Pace', 'If ability during at.', 'by')
# ('William Pace', 'Beyond since form old.', 'rest')
# ('William Pace', 'Boy field require.', 'rest')
# ('William Pace', 'Part include explain.', 'rest')
# ('William Pace', 'Similar you his small.', 'turn')
# ('William Pace', 'Similar you his small.', 'turn')
# ('William Pace', 'Since low help out site.', 'very')
# ('William Pace', 'Since low help out site.', 'very')
# ('William Smith PhD', 'Wonder white learn.', 'a')
# ('William Smith PhD', 'Once able group.', 'a')
# ('William Smith PhD', 'Walk thank community.', 'a')
# ('William Smith PhD', 'Walk thank community.', 'a')
# ('William Smith PhD', 'Industry air sport but.', 'a')
# ('William Smith PhD', 'Industry air sport but.', 'a')
# ('William Smith PhD', 'Once able group.', 'a')
# ('William Smith PhD', 'Wonder white learn.', 'a')
# ('William Smith PhD', 'Only decision scene.', 'a')
# ('William Smith PhD', 'Only decision scene.', 'a')
# ('William Smith PhD', 'Hot test kind play.', 'by')
# ('William Smith PhD', 'But effort much watch.', 'by')
# ('William Smith PhD', 'Seek bring name.', 'hair')
# ('William Smith PhD', 'Operation son then kind.', 'hair')
# ('William Smith PhD', 'Operation son then kind.', 'hair')
# ('William Smith PhD', 'Seek bring name.', 'hair')
# ('William Smith PhD', 'Catch PM oil health.', 'rest')
# ('William Smith PhD', 'Animal piece fill.', 'rest')
# ('William Smith PhD', 'Behind nation future.', 'turn')
# ('William Smith PhD', 'Behind nation future.', 'turn')
# ('William Smith PhD', 'Since low help out site.', 'very')
# ('William Smith PhD', 'Say draw three person.', 'very')
# ('William Smith PhD', 'Since low help out site.', 'very')
# ('William Smith PhD', 'Of respond what.', 'very')
# ('William Smith PhD', 'Owner treat position.', 'very')
# ('William Smith PhD', 'Owner treat position.', 'very')
# ('William Smith PhD', 'Say draw three person.', 'very')
# ('William Smith PhD', 'Of respond what.', 'very')
# ('Willie Alvarado', 'Might it early.', 'a')
# ('Willie Alvarado', 'Might it early.', 'a')
# ('Willie Alvarado', 'Road final power body.', 'a')
# ('Willie Alvarado', 'Road final power body.', 'a')
# ('Willie Alvarado', 'Chance far no.', 'a')
# ('Willie Alvarado', 'Chance far no.', 'a')
# ('Willie Alvarado', 'Might it early.', 'a')
# ('Willie Alvarado', 'Might it early.', 'a')
# ('Willie Alvarado', 'Might it early.', 'a')
# ('Willie Alvarado', 'Might it early.', 'a')
# ('Willie Alvarado', 'Should agency ok out.', 'by')
# ('Willie Alvarado', 'Hot test kind play.', 'by')
# ('Willie Alvarado', 'In say fire.', 'by')
# ('Willie Alvarado', 'Ok kind word too this.', 'by')
# ('Willie Alvarado', 'Person artist team.', 'by')
# ('Willie Alvarado', 'Window common unit it.', 'by')
# ('Willie Alvarado', 'Hot test kind play.', 'by')
# ('Willie Alvarado', 'Staff one play for feel.', 'hair')
# ('Willie Alvarado', 'Staff one play for feel.', 'hair')
# ('Willie Alvarado', 'Boy field require.', 'rest')
# ('Willie Alvarado', 'Relate yeah start.', 'turn')
# ('Willie Alvarado', 'Dark mind meet some.', 'turn')
# ('Willie Alvarado', 'Relate yeah start.', 'turn')
# ('Willie Alvarado', 'Dark mind meet some.', 'turn')
# ('Willie Alvarado', 'Since low help out site.', 'very')
# ('Willie Alvarado', 'Change my explain.', 'very')
# ('Willie Alvarado', 'Since low help out site.', 'very')
# ('Willie Alvarado', 'Since low help out site.', 'very')
# ('Willie Alvarado', 'Owner treat position.', 'very')
# ('Willie Alvarado', 'Owner treat position.', 'very')
# ('Willie Alvarado', 'Since low help out site.', 'very')
# ('Willie Alvarado', 'Since low help out site.', 'very')
# ('Willie Alvarado', 'Since low help out site.', 'very')
# ('Willie Alvarado', 'Change my explain.', 'very')

# %%
# Find the total saved money for each customer

cur.execute("select customer.name, sum(products.price::int) - sum(products.price::int * (100 - sales.discount)/100) as \"Saved Money\" from sales join products on sales.type = products.type join purchases_products_list p on products.id = p.product_id join purchases on p.purchase_id = purchases.id join customer on  purchases.customer_id = customer.id \
    group by customer.name order by customer.name")
for r in cur:
    print(r)
# Out:
# ('Aaron Smith', 2224)
# ('Allison Jordan', 1883)
# ('Amanda Rodriguez', 4)
# ('Amanda Wagner', 1727)
# ('Andrea Neal', 1854)
# ('Angela Black', 2003)
# ('Angela Brown', 541)
# ('Angela Robinson', 1262)
# ('Angela Walker', 534)
# ('Angela Wilson', 345)
# ('Anthony Ruiz', 906)
# ('Barry Howell', 508)
# ('Brian Austin', 764)
# ('Bryan Williams', 1850)
# ('Carrie Bennett', 627)
# ('Catherine Mcdonald', 4807)
# ('Charles Wilkins', 827)
# ('Chase Shah', 2351)
# ('Christopher Mcfarland', 1017)
# ('Colin Robertson', 145)
# ('Danielle Richardson', 1054)
# ('Danny Terry', 1109)
# ('David Barker', 2422)
# ('David Koch', 189)
# ('David Love', 843)
# ('Deborah Jones', 1133)
# ('Denise Gardner', 895)
# ('Diana Wheeler', 769)
# ('Elizabeth Charles', 322)
# ('Eric Edwards', 338)
# ('Erica Howard', 1852)
# ('Gabriela Reid', 878)
# ('Harry Johnson', 551)
# ('Jamie Barker', 918)
# ('Jennifer Caldwell', 389)
# ('Jennifer Rodriguez', 636)
# ('Joshua Conway', 1697)
# ('Joshua Horn', 308)
# ('Justin Gray', 1678)
# ('Justin Hale', 325)
# ('Kathleen Adams', 1193)
# ('Katie Boyd', 481)
# ('Katie Wright', 2091)
# ('Kendra Roach', 702)
# ('Kenneth Turner', 1503)
# ('Kerri Moore', 553)
# ('Kevin House', 1198)
# ('Kevin Paul', 727)
# ('Kimberly Hernandez', 3587)
# ('Kimberly Peterson', 1544)
# ('Laura Carroll', 2644)
# ('Leslie Brown', 1924)
# ('Lindsey Petty', 625)
# ('Lisa Donaldson', 881)
# ('Lisa Hall', 1062)
# ('Mark Thomas', 1862)
# ('Matthew Moore', 1207)
# ('Matthew Tran', 701)
# ('Megan Tucker', 2144)
# ('Michael Ingram', 1072)
# ('Michael Jones', 1055)
# ('Michael Morris', 716)
# ('Michael Ward', 599)
# ('Michael Wright', 1536)
# ('Michaela Arroyo', 2197)
# ('Michele Davis', 1529)
# ('Miguel Chung', 1481)
# ('Misty Santiago', 437)
# ('Monica Larson', 2908)
# ('Ms. Megan Fischer', 1623)
# ('Ms. Monica Harris DVM', 3432)
# ('Peter Williams', 292)
# ('Rebecca Reed', 1008)
# ('Renee Herrera', 934)
# ('Renee Jackson', 364)
# ('Richard Daniel', 1603)
# ('Robert Wagner', 2043)
# ('Rodney Pope', 569)
# ('Sabrina Barry', 2887)
# ('Sabrina Hensley', 2261)
# ('Sarah Chandler', 763)
# ('Sean Morris', 1890)
# ('Stanley Christian', 2693)
# ('Summer Faulkner', 1184)
# ('Tammy Sutton', 216)
# ('Tina Rivera', 2532)
# ('Tony Mcbride', 874)
# ('Tony Scott', 1544)
# ('Tyler Walters', 712)
# ('Tyler Wilkinson', 72)
# ('Victor Davis', 1429)
# ('William Montoya', 2129)
# ('William Pace', 1392)
# ('William Smith PhD', 2383)
# ('Willie Alvarado', 3015)

# %%
cur.execute("create index a on products(type);")
cur.execute("create index b on sales(type);")
